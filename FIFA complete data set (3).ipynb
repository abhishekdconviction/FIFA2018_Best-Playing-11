# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
os.getcwd()
# Out:
# 'C:\\Users\\abhishek\\Documents\\Edureka_Python for datascience\\Fifa Dataset\\complete-fifa-2017-player-dataset-global'

# %%
os.chdir('C://Users/abhishek\Documents\Edureka_Python for datascience\Fifa Dataset\complete-fifa-2017-player-dataset-global')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\abhishek\\Documents\\Edureka_Python for datascience\\Fifa Dataset\\complete-fifa-2017-player-dataset-global'

# %%
fifa_df = pd.read_csv('FullData - sample.csv')
fifa_df.shape
# Out:
# (17588, 53)

# %%
pd.set_option('display.max_columns',53)
fifa_df.head(5)
# Out:
#                 Name Nationality National_Position  National_Kit  \
# 0  Cristiano Ronaldo    Portugal                LS           7.0
# 1       Lionel Messi   Argentina                RW          10.0
# 2             Neymar      Brazil                LW          10.0
# 3        Luis Suárez     Uruguay                LS           9.0
# 4       Manuel Neuer     Germany                GK           1.0
#
#            Club Club_Position  Club_Kit Club_Joining  Contract_Expiry  Rating  \
# 0   Real Madrid            LW       7.0   07/01/2009           2021.0      94
# 1  FC Barcelona            RW      10.0   07/01/2004           2018.0      93
# 2  FC Barcelona            LW      11.0   07/01/2013           2021.0      92
# 3  FC Barcelona            ST       9.0   07/11/2014           2021.0      92
# 4     FC Bayern            GK       1.0   07/01/2011           2021.0      92
#
#    Height Weight Preffered_Foot  Birth_Date  Age Preffered_Position  \
# ...

# %%
del fifa_df['National_Kit']
del fifa_df['Club_Kit']

# %%
fifa_df.head(5)
# Out:
#                 Name Nationality National_Position          Club  \
# 0  Cristiano Ronaldo    Portugal                LS   Real Madrid
# 1       Lionel Messi   Argentina                RW  FC Barcelona
# 2             Neymar      Brazil                LW  FC Barcelona
# 3        Luis Suárez     Uruguay                LS  FC Barcelona
# 4       Manuel Neuer     Germany                GK     FC Bayern
#
#   Club_Position Club_Joining  Contract_Expiry  Rating  Height Weight  \
# 0            LW   07/01/2009           2021.0      94  185 cm  80 kg
# 1            RW   07/01/2004           2018.0      93  170 cm  72 kg
# 2            LW   07/01/2013           2021.0      92  174 cm  68 kg
# 3            ST   07/11/2014           2021.0      92  182 cm  85 kg
# 4            GK   07/01/2011           2021.0      92  193 cm  92 kg
#
#   Preffered_Foot  Birth_Date  Age Preffered_Position        Work_Rate  \
# 0          Right  02/05/1985   32              LW/ST       High / Low
# ...

# %%
NQ_df = fifa_df[(fifa_df['Nationality']=='Italy')]
NQ_df
# Out:
#                         Name Nationality National_Position         Club  \
# 27         Giorgio Chiellini       Italy               LCB     Juventus
# 31          Gianluigi Buffon       Italy                GK     Juventus
# 36          Leonardo Bonucci       Italy                CB     Juventus
# 44            Marco Verratti       Italy               LCM          PSG
# 58         Claudio Marchisio       Italy               NaN     Juventus
# 64           Andrea Barzagli       Italy               RCB     Juventus
# 91           Lorenzo Insigne       Italy               Sub       Napoli
# 139             Mattia Perin       Italy               NaN        Genoa
# 149      Giacomo Bonaventura       Italy               NaN        Milan
# 159       Sebastian Giovinco       Italy               NaN   Toronto FC
# 189         Daniele De Rossi       Italy               CDM         Roma
# 202           Franco Vázquez       Italy               NaN   Sevilla FC
# ...

# %%
fifa_df.head(100)
# Out:
#                   Name         Nationality National_Position  \
# 0    Cristiano Ronaldo            Portugal                LS
# 1         Lionel Messi           Argentina                RW
# 2               Neymar              Brazil                LW
# 3          Luis Suárez             Uruguay                LS
# 4         Manuel Neuer             Germany                GK
# 5               De Gea               Spain                GK
# 6   Robert Lewandowski              Poland                LS
# 7          Gareth Bale               Wales                RS
# 8   Zlatan Ibrahimović              Sweden               NaN
# 9     Thibaut Courtois             Belgium                GK
# 10      Jérôme Boateng             Germany               RCB
# 11         Eden Hazard             Belgium                LF
# 12         Luka Modrić             Croatia               NaN
# 13          Mesut Özil             Germany               CAM
# ...

# %%
fifa_df =fifa_df[(fifa_df.Nationality!='Italy')]
fifa_df = fifa_df[(fifa_df.Nationality!='Netherlands')]

# %%
fifa_df.shape
# Out:
# (16411, 55)

# %%
fifa_df.columns
# Out:
# Index(['Name', 'Nationality', 'National_Position', 'Club', 'Club_Position',
#        'Club_Joining', 'Contract_Expiry', 'Rating', 'Height', 'Weight',
#        'Preffered_Foot', 'Birth_Date', 'Age', 'Preffered_Position',
#        'Work_Rate', 'Weak_foot', 'Skill_Moves', 'Ball_Control', 'Dribbling',
#        'Marking', 'Sliding_Tackle', 'Standing_Tackle', 'Aggression',
#        'Reactions', 'Attacking_Position', 'Interceptions', 'Vision',
#        'Composure', 'Crossing', 'Short_Pass', 'Long_Pass', 'Acceleration',
#        'Speed', 'Stamina', 'Strength', 'Balance', 'Agility', 'Jumping',
#        'Heading', 'Shot_Power', 'Finishing', 'Long_Shots', 'Curve',
#        'Freekick_Accuracy', 'Penalties', 'Volleys', 'GK_Positioning',
#        'GK_Diving', 'GK_Kicking', 'GK_Handling', 'GK_Reflexes', 'Shot_Stopper',
#        'Sweeper', 'Best_Centre_Backs', 'Best_Wing_Backs'],
#       dtype='object')

# %%
sns.set(rc={'figure.figsize':(20,100)})
sns.countplot(y= 'Nationality',data =fifa_df, palette='Set2')

# %%
sns.set(rc ={'figure.figsize':(50,20)})
sns.countplot(x=fifa_df.Age)

# %%
#weights
a= 0.5
b = 1
c = 2
d= 3
#find out the best defender
fifa_df.head(5)
# Out:
#                 Name Nationality National_Position          Club  \
# 0  Cristiano Ronaldo    Portugal                LS   Real Madrid
# 1       Lionel Messi   Argentina                RW  FC Barcelona
# 2             Neymar      Brazil                LW  FC Barcelona
# 3        Luis Suárez     Uruguay                LS  FC Barcelona
# 4       Manuel Neuer     Germany                GK     FC Bayern
#
#   Club_Position Club_Joining  Contract_Expiry  Rating  Height Weight  \
# 0            LW   07/01/2009           2021.0      94  185 cm  80 kg
# 1            RW   07/01/2004           2018.0      93  170 cm  72 kg
# 2            LW   07/01/2013           2021.0      92  174 cm  68 kg
# 3            ST   07/11/2014           2021.0      92  182 cm  85 kg
# 4            GK   07/01/2011           2021.0      92  193 cm  92 kg
#
#   Preffered_Foot  Birth_Date  Age Preffered_Position        Work_Rate  \
# 0          Right  02/05/1985   32              LW/ST       High / Low
# ...

# %%
#goalkeeping characteristics
fifa_df['Shot_Stopper'] = (b*fifa_df.Reactions+b*fifa_df.Composure+a*fifa_df.Speed+c*fifa_df.Jumping+
                           b*fifa_df.GK_Positioning+d*fifa_df.GK_Diving+b*fifa_df.GK_Kicking+
                           b*fifa_df.GK_Handling+d*fifa_df.GK_Reflexes)/(a+5*b+c+2*d)

# %%
plt.figure(figsize = (15,6))
#generate sequential data and plot
sd1 = fifa_df.sort_values('Shot_Stopper', ascending = False)[:5]
sd1
# Out:
#                  Name Nationality National_Position            Club  \
# 4        Manuel Neuer     Germany                GK       FC Bayern
# 5              De Gea       Spain                GK  Manchester Utd
# 40   Samir Handanovič    Slovenia               NaN           Inter
# 138     Anthony Lopes    Portugal               Sub  Olym. Lyonnais
# 26        Hugo Lloris      France                GK           Spurs
#
#     Club_Position Club_Joining  Contract_Expiry  Rating  Height Weight  \
# 4              GK   07/01/2011           2021.0      92  193 cm  92 kg
# 5              GK   07/01/2011           2019.0      90  193 cm  82 kg
# 40             GK   07/01/2012           2019.0      87  193 cm  89 kg
# 138            GK   06/11/2010           2020.0      83  184 cm  81 kg
# 26             GK   08/01/2012           2022.0      88  188 cm  82 kg
#
#     Preffered_Foot  Birth_Date  Age Preffered_Position        Work_Rate  \
# ...

# %%
sd1
x1 = np.array(list(sd1['Name']))
y1 = np.array(list(sd1['Shot_Stopper']))
#plt.bar(x1,y1)
#plt.rcParams["axes.labelsize"] = 15
#sns.set_context("paper", rc={"font.size":18,"axes.titlesize":15,"axes.labelsize":10})   
plt.xlabel('Name', fontsize ='50')
plt.ylabel('Shot Stopping Score', fontsize ='50')
#plt.xticks(['Manuel Neur', 'De Gea','Samir Handanovič','Anthony Lopes','Hugo Lloris'])
#plt.yticks([20,40,60,80,100,120,140])
sns.barplot(x1,y1, palette = 'colorblind')

# %%
fifa_df.head(3)
# Out:
#                 Name Nationality National_Position          Club  \
# 0  Cristiano Ronaldo    Portugal                LS   Real Madrid
# 1       Lionel Messi   Argentina                RW  FC Barcelona
# 2             Neymar      Brazil                LW  FC Barcelona
#
#   Club_Position Club_Joining  Contract_Expiry  Rating  Height Weight  \
# 0            LW   07/01/2009           2021.0      94  185 cm  80 kg
# 1            RW   07/01/2004           2018.0      93  170 cm  72 kg
# 2            LW   07/01/2013           2021.0      92  174 cm  68 kg
#
#   Preffered_Foot  Birth_Date  Age Preffered_Position        Work_Rate  \
# 0          Right  02/05/1985   32              LW/ST       High / Low
# 1           Left  06/24/1987   29                 RW  Medium / Medium
# 2          Right  02/05/1992   25                 LW    High / Medium
#
#    Weak_foot  Skill_Moves  Ball_Control  Dribbling  Marking  Sliding_Tackle  \
# ...

# %%
pd.set_option('display.max_columns',53)
#pd.set_option('display.max_columns',53)
fifa_df.head(5)
# Out:
#                 Name Nationality National_Position          Club  \
# 0  Cristiano Ronaldo    Portugal                LS   Real Madrid
# 1       Lionel Messi   Argentina                RW  FC Barcelona
# 2             Neymar      Brazil                LW  FC Barcelona
# 3        Luis Suárez     Uruguay                LS  FC Barcelona
# 4       Manuel Neuer     Germany                GK     FC Bayern
#
#   Club_Position Club_Joining  Contract_Expiry  Rating  Height Weight  \
# 0            LW   07/01/2009           2021.0      94  185 cm  80 kg
# 1            RW   07/01/2004           2018.0      93  170 cm  72 kg
# 2            LW   07/01/2013           2021.0      92  174 cm  68 kg
# 3            ST   07/11/2014           2021.0      92  182 cm  85 kg
# 4            GK   07/01/2011           2021.0      92  193 cm  92 kg
#
#   Preffered_Foot  Birth_Date  Age Preffered_Position        Work_Rate  \
# 0          Right  02/05/1985   32              LW/ST       High / Low
# ...

# %%
fifa_df['Sweeper'] = (b*fifa_df.Reactions+b*fifa_df.Vision+b*fifa_df.Speed+
                         a*fifa_df.Short_Pass+a*fifa_df.Long_Pass+b*fifa_df.Jumping+
                         b*fifa_df.GK_Positioning+b*fifa_df.GK_Diving+d*fifa_df.GK_Kicking+
                         b*fifa_df.GK_Handling+d*fifa_df.GK_Reflexes+c*fifa_df.Vision
                        )/(7*b+2*b+c+2*d)

# %%
sf2 = fifa_df.sort_values('Sweeper', ascending =False)[:5]
sf2
# Out:
#               Name Nationality National_Position             Club  \
# 4     Manuel Neuer     Germany                GK        FC Bayern
# 5           De Gea       Spain                GK   Manchester Utd
# 168  Claudio Bravo       Chile                GK  Manchester City
# 190     José Reina       Spain               Sub           Napoli
# 164   Rui Patrício    Portugal                GK      Sporting CP
#
#     Club_Position Club_Joining  Contract_Expiry  Rating  Height Weight  \
# 4              GK   07/01/2011           2021.0      92  193 cm  92 kg
# 5              GK   07/01/2011           2019.0      90  193 cm  82 kg
# 168           Sub   08/25/2016           2020.0      83  184 cm  80 kg
# 190            GK   07/01/2015           2018.0      83  188 cm  92 kg
# 164            GK   06/01/2006           2022.0      83  190 cm  84 kg
#
#     Preffered_Foot  Birth_Date  Age Preffered_Position        Work_Rate  \
# ...

# %%
sns.set(rc={'figure.figsize':(20,10)})

# %%
x2= np.array(list(sf2['Name']))
y2= np.array(list(sf2['Sweeper']))
#plt.bar(x2,y2)
sns.barplot(x2,y2,palette ='colorblind')
plt.xlabel('Name', fontsize ='25',color ='Red')
plt.ylabel('Sweeper Goalkeeprr Score', fontsize ='25', color ='Red')
# Out:
# Text(0, 0.5, 'Sweeper Goalkeeprr Score')

# %%
#Finding the best defenders
pd.set_option('display.max_column',53)
fifa_df.head(5)
# Out:
#                 Name Nationality National_Position          Club  \
# 0  Cristiano Ronaldo    Portugal                LS   Real Madrid
# 1       Lionel Messi   Argentina                RW  FC Barcelona
# 2             Neymar      Brazil                LW  FC Barcelona
# 3        Luis Suárez     Uruguay                LS  FC Barcelona
# 4       Manuel Neuer     Germany                GK     FC Bayern
#
#   Club_Position Club_Joining  Contract_Expiry  Rating  Height Weight  \
# 0            LW   07/01/2009           2021.0      94  185 cm  80 kg
# 1            RW   07/01/2004           2018.0      93  170 cm  72 kg
# 2            LW   07/01/2013           2021.0      92  174 cm  68 kg
# 3            ST   07/11/2014           2021.0      92  182 cm  85 kg
# 4            GK   07/01/2011           2021.0      92  193 cm  92 kg
#
#   Preffered_Foot  Birth_Date  Age Preffered_Position        Work_Rate  \
# 0          Right  02/05/1985   32              LW/ST       High / Low
# ...

# %%
fifa_df.groupby('Name').get_group('Leonardo Bonucci')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-131-d9518900a9ca> in <module>
# ----> 1 fifa_df.groupby('Name').get_group('Leonardo Bonucci')
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in get_group(self, name, obj)
#     646         inds = self._get_index(name)
#     647         if not len(inds):
# --> 648             raise KeyError(name)
#     649
#     650         return obj._take(inds, axis=self.axis)
#
# KeyError: 'Leonardo Bonucci'

# %%
fifa_df.groupby('Name').get_group('Mats Hummels')
# Out:
#             Name Nationality National_Position       Club Club_Position  \
# 25  Mats Hummels     Germany               LCB  FC Bayern           LCB
#
#    Club_Joining  Contract_Expiry  Rating  Height Weight Preffered_Foot  \
# 25   07/01/2016           2021.0      88  191 cm  92 kg          Right
#
#     Birth_Date  Age Preffered_Position      Work_Rate  Weak_foot  Skill_Moves  \
# 25  12/16/1988   28                 CB  High / Medium          3            2
#
#     Ball_Control  Dribbling  Marking  Sliding_Tackle  Standing_Tackle  \
# 25            77         68       85              87               92
#
#     Aggression  Reactions  Attacking_Position  Interceptions  ...  Short_Pass  \
# 25          66         85                  56             89  ...          78
#
#     Long_Pass  Acceleration  Speed  Stamina  Strength  Balance  Agility  \
# 25         82            62     65       66        85       58       64
#
# ...

# %%
fifa_df['Best_Centre_Backs'] = (c*fifa_df.Sliding_Tackle+ d*fifa_df.Standing_Tackle+d*fifa_df.Marking+
                                c*fifa_df.Reactions+d*fifa_df.Interceptions+b*fifa_df.Vision+
                                b*fifa_df.Composure+a*fifa_df.Short_Pass+a*fifa_df.Long_Pass+
                                a*fifa_df.Speed+a*fifa_df.Stamina+c*fifa_df.Strength+a*fifa_df.Heading)/(5*a+2*b+3*c+3*d)

# %%
sn3 = fifa_df[(fifa_df['Club_Position']=='LCB')].sort_values('Best_Centre_Backs',ascending = False)[:5]
sn4 = fifa_df[(fifa_df['Club_Position']=='RCB')].sort_values('Best_Centre_Backs',ascending = False)[:5]
sn3
# Out:
#                Name Nationality National_Position             Club  \
# 15     Thiago Silva      Brazil               Sub              PSG
# 25     Mats Hummels     Germany               LCB        FC Bayern
# 16     Sergio Ramos       Spain               LCB      Real Madrid
# 24      Diego Godín     Uruguay               LCB  Atlético Madrid
# 85  Aymeric Laporte      France               NaN  Athletic Bilbao
#
#    Club_Position Club_Joining  Contract_Expiry  Rating  Height Weight  \
# 15           LCB   07/01/2012           2020.0      89  183 cm  79 kg
# 25           LCB   07/01/2016           2021.0      88  191 cm  92 kg
# 16           LCB   08/01/2005           2020.0      89  183 cm  75 kg
# 24           LCB   08/01/2010           2019.0      88  185 cm  73 kg
# 85           LCB   10/01/2012           2020.0      84  189 cm  85 kg
#
#    Preffered_Foot  Birth_Date  Age Preffered_Position        Work_Rate  \
# ...

# %%
sn4
# Out:
#               Name Nationality National_Position          Club Club_Position  \
# 41           Piqué       Spain               RCB  FC Barcelona           RCB
# 59         Miranda      Brazil               RCB         Inter           RCB
# 158    Azpilicueta       Spain               Sub       Chelsea           RCB
# 75   Javi Martinez       Spain               Sub     FC Bayern           RCB
# 29            Pepe    Portugal               RCB   Real Madrid           RCB
#
#     Club_Joining  Contract_Expiry  Rating  Height Weight Preffered_Foot  \
# 41    07/01/2008           2019.0      87  193 cm  85 kg          Right
# 59    07/03/2015           2018.0      86  186 cm  78 kg          Right
# 158   08/24/2012           2020.0      83  178 cm  75 kg          Right
# 75    08/29/2012           2021.0      85  190 cm  81 kg          Right
# 29    07/01/2007           2017.0      88  188 cm  81 kg          Right
#
# ...

# %%
pd.set_option('display.max_column', 56)
sns.set(rc={'figure.figsize':(10,7)})
x3 = np.array(list(sn3['Name']))
y3 = np.array(list(sn3['Best_Centre_Backs']))
plt.xlabel('Name',fontsize = 20, color ='Green')
plt.ylabel('Centre Back Score',fontsize = 20, color ='Green'), 
sns.barplot(x3,y3, palette ='colorblind')

# %%
sns.set(rc={'figure.figsize':(10,9)})
x4 = np.array(list(sn4['Name']))
y4 = np.array(list(sn4['Best_Centre_Backs']))
plt.xlabel('Name',fontsize =20, color ='Green')
plt.ylabel('Best Centre Back Score',fontsize =20, color ='Green')
sns.barplot(x4,y4, palette ='colorblind')

# %%
fifa_df[(fifa_df['Club_Position']=='RB')][:3]
# Out:
#              Name Nationality National_Position             Club  \
# 28   Philipp Lahm     Germany               NaN        FC Bayern
# 87       Carvajal       Spain                RB      Real Madrid
# 184      Juanfran       Spain               NaN  Atlético Madrid
#
#     Club_Position Club_Joining  Contract_Expiry  Rating  Height Weight  \
# 28             RB   11/01/2002           2018.0      88  170 cm  66 kg
# 87             RB   07/05/2013           2020.0      84  173 cm  73 kg
# 184            RB   01/01/2011           2018.0      83  180 cm  72 kg
#
#     Preffered_Foot  Birth_Date  Age Preffered_Position      Work_Rate  \
# 28           Right  11/11/1983   33              RB/CM  Medium / High
# 87           Right  01/11/1992   25                 RB  High / Medium
# 184          Right  01/09/1985   32                 RB  High / Medium
#
#      Weak_foot  Skill_Moves  Ball_Control  Dribbling  Marking  Sliding_Tackle  \
# ...

# %%
fifa_df['Best_Wing_Backs'] = (d*fifa_df.Sliding_Tackle+ c*fifa_df.Standing_Tackle+d*fifa_df.Marking+
                                c*fifa_df.Reactions+d*fifa_df.Interceptions+b*fifa_df.Vision+
                                b*fifa_df.Composure+a*fifa_df.Short_Pass+b*fifa_df.Long_Pass+
                                c*fifa_df.Speed+b*fifa_df.Stamina+b*fifa_df.Strength+
                                a*fifa_df.Heading)/(2*a+5*b+3*c+3*d)

# %%
sn5 = fifa_df[(fifa_df['Club_Position']=='LB')].sort_values('Best_Wing_Backs',ascending =False)[:5]

# %%
sn5
# Out:
#             Name Nationality National_Position             Club Club_Position  \
# 45   David Alaba     Austria                LM        FC Bayern            LB
# 83   Filipe Luís      Brazil               Sub  Atlético Madrid            LB
# 57       Marcelo      Brazil                LB      Real Madrid            LB
# 99   Alex Sandro      Brazil               NaN         Juventus            LB
# 672  Ştefan Radu     Romania               NaN            Lazio            LB
#
#     Club_Joining  Contract_Expiry  Rating  Height Weight Preffered_Foot  \
# 45    02/10/2010           2021.0      86  180 cm  76 kg           Left
# 83    07/29/2015           2019.0      85  182 cm  77 kg           Left
# 57    01/01/2007           2020.0      86  174 cm  75 kg           Left
# 99    08/21/2015           2020.0      84  181 cm  76 kg           Left
# 672   01/01/2008           2020.0      79  183 cm  79 kg           Left
#
# ...

# %%
sn6 = fifa_df[(fifa_df['Club_Position']=='RB')].sort_values('Best_Wing_Backs',ascending =False)[:5]
sn6
# Out:
#                      Name  Nationality National_Position              Club  \
# 28           Philipp Lahm      Germany               NaN         FC Bayern
# 87               Carvajal        Spain                RB       Real Madrid
# 259      Antonio Valencia      Ecuador                RM    Manchester Utd
# 372           Darijo Srna      Croatia               NaN  Shakhtar Donetsk
# 187  Stephan Lichtsteiner  Switzerland                RB          Juventus
#
#     Club_Position Club_Joining  Contract_Expiry  Rating  Height Weight  \
# 28             RB   11/01/2002           2018.0      88  170 cm  66 kg
# 87             RB   07/05/2013           2020.0      84  173 cm  73 kg
# 259            RB   06/30/2009           2018.0      82  181 cm  78 kg
# 372            RB   07/01/2003           2021.0      81  178 cm  72 kg
# 187            RB   07/01/2011           2018.0      83  182 cm  74 kg
#
#     Preffered_Foot  Birth_Date  Age Preffered_Position      Work_Rate  \
# ...

# %%
sns.set(rc={'figure.figsize':(10,7)})
x5 = np.array(list(sn5['Name']))
y5 = np.array(list(sn5['Best_Wing_Backs']))
plt.xlabel('Name', fontsize = 20, Color ='Red')
plt.ylabel('Left Back Score', fontsize = 20, Color ='Red')
sns.barplot(x5,y5, palette = 'colorblind')

# %%
sns.set(rc={'figure.figsize':(10,7)})
x6 = np.array(list(sn6['Name']))
y6 = np.array(list(sn6['Best_Wing_Backs']))
plt.xlabel('Name', fontsize = 20, Color ='Red')
plt.ylabel('Right Back Score', fontsize = 20, Color ='Red')
sns.barplot(x6,y6, palette = 'colorblind')

# %%
pd.set_option('display.max_column',57)
fifa_df.head(20)
fifa_df[(fifa_df['Club_Position']=='RCM')].head(5)
# Out:
#                 Name Nationality National_Position             Club  \
# 12       Luka Modrić     Croatia               NaN      Real Madrid
# 20   Kevin De Bruyne     Belgium               RCM  Manchester City
# 121     N'Golo Kanté      France               RDM          Chelsea
# 145    Ander Herrera       Spain               Sub   Manchester Utd
# 162     Adam Lallana     England                LM        Liverpool
#
#     Club_Position Club_Joining  Contract_Expiry  Rating  Height Weight  \
# 12            RCM   08/01/2012           2020.0      89  174 cm  65 kg
# 20            RCM   08/30/2015           2021.0      88  181 cm  68 kg
# 121           RCM   07/16/2016           2021.0      83  168 cm  68 kg
# 145           RCM   06/26/2014           2018.0      83  182 cm  73 kg
# 162           RCM   07/01/2014           2021.0      83  172 cm  73 kg
#
#     Preffered_Foot  Birth_Date  Age Preffered_Position      Work_Rate  \
# ...

# %%
#best midfielders
fifa_df['Best Right Central Midfielder']= (b*fifa_df.Ball_Control+a*fifa_df.Dribbling+b*fifa_df.Marking+
                                          c*fifa_df.Sliding_Tackle+c*fifa_df.Standing_Tackle+b*fifa_df.Aggression+
                                           d*fifa_df.Interceptions+b*fifa_df.Vision+c*fifa_df.Composure+
                                           b*fifa_df.Short_Pass+b*fifa_df.Long_Pass+b*fifa_df.Acceleration+
                                           b*fifa_df.Speed+c*fifa_df.Stamina+c*fifa_df.Strength+
                                           d*fifa_df.Balance+c*fifa_df.Agility+b*fifa_df.Jumping+
                                           b*fifa_df.Heading+b*fifa_df.Shot_Power+a*fifa_df.Finishing+
                                           b*fifa_df.Long_Shots+b*fifa_df.Penalties)/(2*a+13*b+6*c+2*d)

# %%
sn7 = fifa_df[(fifa_df['Club_Position']== 'RCM')].sort_values('Best Right Central Midfielder', ascending = False)[:5]

# %%
sn7
# Out:
#                  Name Nationality National_Position            Club  \
# 121      N'Golo Kanté      France               RDM         Chelsea
# 12        Luka Modrić     Croatia               NaN     Real Madrid
# 778        Enzo Pérez   Argentina               Sub     Valencia CF
# 145     Ander Herrera       Spain               Sub  Manchester Utd
# 848  Zlatko Junuzović     Austria               RCM   Werder Bremen
#
#     Club_Position Club_Joining  Contract_Expiry  Rating  Height Weight  \
# 121           RCM   07/16/2016           2021.0      83  168 cm  68 kg
# 12            RCM   08/01/2012           2020.0      89  174 cm  65 kg
# 778           RCM   01/01/2015           2019.0      78  177 cm  71 kg
# 145           RCM   06/26/2014           2018.0      83  182 cm  73 kg
# 848           RCM   01/27/2012           2018.0      78  172 cm  69 kg
#
#     Preffered_Foot  Birth_Date  Age Preffered_Position        Work_Rate  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
x7= np.array(list(sn7['Name']))
y7= np.array(list(sn7['Best Right Central Midfielder']))
plt.xlabel("Name")
plt.ylabel(" Best Central Midfielder Score")
sns.barplot(x7,y7, palette ='colorblind')

# %%
fifa_df[(fifa_df['Club_Position']=='LCM')].head(5)
# Out:
#               Name Nationality National_Position             Club  \
# 18      Paul Pogba      France               NaN   Manchester Utd
# 23      Toni Kroos     Germany               LDM      Real Madrid
# 39     David Silva       Spain                LM  Manchester City
# 79    Marek Hamšik    Slovakia               NaN           Napoli
# 80  Blaise Matuidi      France               LDM              PSG
#
#    Club_Position Club_Joining  Contract_Expiry  Rating  Height Weight  \
# 18           LCM   08/09/2016           2021.0      88  191 cm  84 kg
# 23           LCM   07/17/2014           2022.0      88  182 cm  78 kg
# 39           LCM   07/14/2010           2019.0      87  173 cm  67 kg
# 79           LCM   07/01/2007           2020.0      85  183 cm  79 kg
# 80           LCM   07/01/2011           2018.0      85  175 cm  70 kg
#
#    Preffered_Foot  Birth_Date  Age Preffered_Position        Work_Rate  \
# 18          Right  03/15/1993   24             CM/CAM    High / Medium
# ...

# %%
fifa_df['Best Left Central Midfielder']= (b*fifa_df.Ball_Control+a*fifa_df.Dribbling+b*fifa_df.Marking+
                                          c*fifa_df.Sliding_Tackle+c*fifa_df.Standing_Tackle+b*fifa_df.Aggression+
                                           d*fifa_df.Interceptions+b*fifa_df.Vision+c*fifa_df.Composure+
                                           b*fifa_df.Short_Pass+b*fifa_df.Long_Pass+b*fifa_df.Acceleration+
                                           b*fifa_df.Speed+c*fifa_df.Stamina+c*fifa_df.Strength+
                                           d*fifa_df.Balance+c*fifa_df.Agility+b*fifa_df.Jumping+
                                           b*fifa_df.Heading+b*fifa_df.Shot_Power+a*fifa_df.Finishing+
                                           b*fifa_df.Long_Shots+b*fifa_df.Penalties)/(2*a+13*b+6*c+2*d)

# %%
sn8 = fifa_df[(fifa_df['Club_Position']== 'LCM')].sort_values('Best Left Central Midfielder', ascending = False)[:5]
sn8
# Out:
#                  Name Nationality National_Position             Club  \
# 80     Blaise Matuidi      France               LDM              PSG
# 18         Paul Pogba      France               NaN   Manchester Utd
# 265    Moussa Dembélé     Belgium               Sub            Spurs
# 289  Corentin Tolisso      France               Sub   Olym. Lyonnais
# 294     Morgan Sanson      France               NaN  Olym. Marseille
#
#     Club_Position Club_Joining  Contract_Expiry  Rating  Height Weight  \
# 80            LCM   07/01/2011           2018.0      85  175 cm  70 kg
# 18            LCM   08/09/2016           2021.0      88  191 cm  84 kg
# 265           LCM   08/01/2012           2019.0      82  185 cm  88 kg
# 289           LCM   08/01/2013           2020.0      81  181 cm  78 kg
# 294           LCM   01/18/2017           2021.0      81  180 cm  72 kg
#
#     Preffered_Foot  Birth_Date  Age Preffered_Position        Work_Rate  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
x8 = np.array(list(sn8['Name']))
y8 = np.array(list(sn8['Best Left Central Midfielder']))
plt.xlabel('Name')
plt.ylabel('Best Left Central Defender Score')
sns.barplot(x8,y8, palette ='colorblind')

# %%
pd.set_option('Display.max_column',59)
fifa_df[(fifa_df['Club_Position']=='CAM')].head(5)
# Out:
#                Name Nationality National_Position          Club Club_Position  \
# 13       Mesut Özil     Germany               CAM       Arsenal           CAM
# 34  James Rodríguez    Colombia               LAM   Real Madrid           CAM
# 38     Ivan Rakitić     Croatia               NaN  FC Barcelona           CAM
# 43     Paulo Dybala   Argentina               Sub      Juventus           CAM
# 48    Thomas Müller     Germany                RM     FC Bayern           CAM
#
#    Club_Joining  Contract_Expiry  Rating  Height Weight Preffered_Foot  \
# 13   09/02/2013           2018.0      89  180 cm  76 kg           Left
# 34   07/22/2014           2020.0      87  180 cm  75 kg           Left
# 38   06/24/2014           2021.0      87  184 cm  78 kg          Right
# 43   07/01/2015           2020.0      86  177 cm  74 kg           Left
# 48   08/10/2008           2021.0      86  186 cm  75 kg          Right
#
#     Birth_Date  Age Preffered_Position        Work_Rate  Weak_foot  \
# ...

# %%
fifa_df['Best Central Attacking Midfielder']= (c*fifa_df.Ball_Control+c*fifa_df.Dribbling+a*fifa_df.Marking+
                                          a*fifa_df.Sliding_Tackle+b*fifa_df.Standing_Tackle+b*fifa_df.Aggression+
                                           b*fifa_df.Interceptions+d*fifa_df.Vision+c*fifa_df.Composure+d*fifa_df.Crossing+
                                           d*fifa_df.Short_Pass+c*fifa_df.Long_Pass+b*fifa_df.Acceleration+
                                           b*fifa_df.Speed+b*fifa_df.Stamina+d*fifa_df.Balance+c*fifa_df.Agility+
                                          b*fifa_df.Jumping+b*fifa_df.Heading+b*fifa_df.Shot_Power+
                                          b*fifa_df.Finishing+c*fifa_df.Long_Shots+b*fifa_df.Penalties+
                                          c*fifa_df.Attacking_Position+c*fifa_df.Reactions+
                                          c*fifa_df.Freekick_Accuracy+c*fifa_df.Volleys)/(2*a+11*b+10*c+4*d)

# %%
sn9 = fifa_df[(fifa_df['Club_Position']== 'CAM')].sort_values('Best Central Attacking Midfielder', ascending = False)[:5]
sn9
# Out:
#                   Name Nationality National_Position          Club  \
# 34     James Rodríguez    Colombia               LAM   Real Madrid
# 43        Paulo Dybala   Argentina               Sub      Juventus
# 38        Ivan Rakitić     Croatia               NaN  FC Barcelona
# 111        Éver Banega   Argentina               CAM         Inter
# 69   Christian Eriksen     Denmark                CM         Spurs
#
#     Club_Position Club_Joining  Contract_Expiry  Rating  Height Weight  \
# 34            CAM   07/22/2014           2020.0      87  180 cm  75 kg
# 43            CAM   07/01/2015           2020.0      86  177 cm  74 kg
# 38            CAM   06/24/2014           2021.0      87  184 cm  78 kg
# 111           CAM   07/06/2016           2020.0      84  174 cm  71 kg
# 69            CAM   08/30/2013           2018.0      85  180 cm  76 kg
#
#     Preffered_Foot  Birth_Date  Age Preffered_Position        Work_Rate  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
x9 = np.array(list(sn9['Name']))
y9 = np.array(list(sn9['Best Central Attacking Midfielder']))
plt.xlabel('Name')
plt.ylabel('Best Left Central Defender Score')
sns.barplot(x9,y9, palette ='colorblind')

# %%
fifa_df[(fifa_df['Club_Position']== 'LW')].head(3)
#fifa_df.head(100)
# Out:
#                  Name Nationality National_Position          Club  \
# 0   Cristiano Ronaldo    Portugal                LS   Real Madrid
# 2              Neymar      Brazil                LW  FC Barcelona
# 11        Eden Hazard     Belgium                LF       Chelsea
#
#    Club_Position Club_Joining  Contract_Expiry  Rating  Height Weight  \
# 0             LW   07/01/2009           2021.0      94  185 cm  80 kg
# 2             LW   07/01/2013           2021.0      92  174 cm  68 kg
# 11            LW   07/01/2012           2020.0      89  173 cm  74 kg
#
#    Preffered_Foot  Birth_Date  Age Preffered_Position      Work_Rate  \
# 0           Right  02/05/1985   32              LW/ST     High / Low
# 2           Right  02/05/1992   25                 LW  High / Medium
# 11          Right  01/07/1991   26              LW/LM  High / Medium
#
#     Weak_foot  Skill_Moves  Ball_Control  Dribbling  Marking  Sliding_Tackle  \
# ...

# %%
fifa_df['Best Left Winger']= (d*fifa_df.Ball_Control+d*fifa_df.Dribbling+b*fifa_df.Aggression+
                              c*fifa_df.Vision+c*fifa_df.Composure+c*fifa_df.Crossing+
                              c*fifa_df.Short_Pass+b*fifa_df.Long_Pass+d*fifa_df.Acceleration+
                              d*fifa_df.Speed+c*fifa_df.Stamina+b*fifa_df.Balance+
                              d*fifa_df.Agility+b*fifa_df.Jumping+c*fifa_df.Heading+
                              c*fifa_df.Shot_Power+c*fifa_df.Finishing+c*fifa_df.Long_Shots+
                              c*fifa_df.Penalties+ d*fifa_df.Attacking_Position+c*fifa_df.Reactions+
                              c*fifa_df.Freekick_Accuracy+c*fifa_df.Volleys+c*fifa_df.Curve+
                              b*fifa_df.Strength)/(4*b+14*c+6*d)

# %%
sn10 = fifa_df[(fifa_df['Club_Position']== 'LW')].sort_values('Best Left Winger', ascending = False)[:5]
sn10
# Out:
#                  Name Nationality National_Position             Club  \
# 0   Cristiano Ronaldo    Portugal                LS      Real Madrid
# 2              Neymar      Brazil                LW     FC Barcelona
# 21         Marco Reus     Germany               NaN    Bor. Dortmund
# 11        Eden Hazard     Belgium                LF          Chelsea
# 76      Dimitri Payet      France                LM  Olym. Marseille
#
#    Club_Position Club_Joining  Contract_Expiry  Rating  Height Weight  \
# 0             LW   07/01/2009           2021.0      94  185 cm  80 kg
# 2             LW   07/01/2013           2021.0      92  174 cm  68 kg
# 21            LW   07/01/2012           2019.0      88  182 cm  76 kg
# 11            LW   07/01/2012           2020.0      89  173 cm  74 kg
# 76            LW   01/29/2017           2021.0      85  175 cm  77 kg
#
#    Preffered_Foot  Birth_Date  Age Preffered_Position        Work_Rate  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
x10 = np.array(list(sn10['Name']))
y10 = np.array(list(sn10['Best Left Winger']))
plt.xlabel('Name', fontsize =20, color ='Red')
plt.ylabel('Best Left Winger', fontsize = 20, color ='Green')
sns.barplot(x10,y10, palette ='colorblind')

# %%
fifa_df['Best Right Winger']= (d*fifa_df.Ball_Control+d*fifa_df.Dribbling+b*fifa_df.Aggression+
                              c*fifa_df.Vision+c*fifa_df.Composure+c*fifa_df.Crossing+
                              c*fifa_df.Short_Pass+b*fifa_df.Long_Pass+d*fifa_df.Acceleration+
                              d*fifa_df.Speed+c*fifa_df.Stamina+b*fifa_df.Balance+
                              d*fifa_df.Agility+b*fifa_df.Jumping+c*fifa_df.Heading+
                              c*fifa_df.Shot_Power+c*fifa_df.Finishing+c*fifa_df.Long_Shots+
                              c*fifa_df.Penalties+ d*fifa_df.Attacking_Position+c*fifa_df.Reactions+
                              c*fifa_df.Freekick_Accuracy+c*fifa_df.Volleys+c*fifa_df.Curve+
                              b*fifa_df.Strength)/(4*b+14*c+6*d)

# %%
sn11 = fifa_df[(fifa_df['Club_Position']== 'RW')].sort_values('Best Right Winger', ascending = False)[:5]
sn11
# Out:
#                    Name Nationality National_Position            Club  \
# 1          Lionel Messi   Argentina                RW    FC Barcelona
# 7           Gareth Bale       Wales                RS     Real Madrid
# 53       Ángel Di María   Argentina                LW             PSG
# 46   Henrikh Mkhitaryan     Armenia               NaN  Manchester Utd
# 142          Iago Aspas       Spain               Sub      Celta Vigo
#
#     Club_Position Club_Joining  Contract_Expiry  Rating  Height Weight  \
# 1              RW   07/01/2004           2018.0      93  170 cm  72 kg
# 7              RW   09/02/2013           2022.0      90  183 cm  74 kg
# 53             RW   08/06/2015           2019.0      86  180 cm  75 kg
# 46             RW   07/06/2016           2020.0      86  177 cm  75 kg
# 142            RW   07/01/2015           2020.0      83  176 cm  67 kg
#
#     Preffered_Foot  Birth_Date  Age Preffered_Position        Work_Rate  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
x11 = np.array(list(sn11['Name']))
y11 = np.array(list(sn11['Best Right Winger']))
plt.xlabel('Name', fontsize =20, color ='Red')
plt.ylabel('Best Right Winger', fontsize = 20, color ='Green')
sns.barplot(x11,y11, palette ='colorblind')

# %%
pd.set_option('Display.max_column',62)
fifa_df[(fifa_df['Club_Position']=='ST')].head(3)
# Out:
#                  Name Nationality National_Position            Club  \
# 3         Luis Suárez     Uruguay                LS    FC Barcelona
# 6  Robert Lewandowski      Poland                LS       FC Bayern
# 8  Zlatan Ibrahimović      Sweden               NaN  Manchester Utd
#
#   Club_Position Club_Joining  Contract_Expiry  Rating  Height Weight  \
# 3            ST   07/11/2014           2021.0      92  182 cm  85 kg
# 6            ST   07/01/2014           2021.0      90  185 cm  79 kg
# 8            ST   07/01/2016           2017.0      90  195 cm  95 kg
#
#   Preffered_Foot  Birth_Date  Age Preffered_Position      Work_Rate  \
# 3          Right  01/24/1987   30                 ST  High / Medium
# 6          Right  08/21/1988   28                 ST  High / Medium
# 8          Right  10/03/1981   35                 ST   Medium / Low
#
#    Weak_foot  Skill_Moves  Ball_Control  Dribbling  Marking  Sliding_Tackle  \
# ...

# %%
fifa_df['Best Striker']= (d*fifa_df.Ball_Control+d*fifa_df.Dribbling+c*fifa_df.Aggression+
                          c*fifa_df.Vision+c*fifa_df.Composure+c*fifa_df.Crossing+
                          c*fifa_df.Short_Pass+b*fifa_df.Long_Pass+c*fifa_df.Acceleration+
                          c*fifa_df.Speed+c*fifa_df.Stamina+b*fifa_df.Balance+
                          d*fifa_df.Agility+b*fifa_df.Jumping+c*fifa_df.Heading+
                          d*fifa_df.Shot_Power+d*fifa_df.Finishing+c*fifa_df.Long_Shots+
                          c*fifa_df.Penalties+ d*fifa_df.Attacking_Position+d*fifa_df.Reactions+
                          c*fifa_df.Freekick_Accuracy+c*fifa_df.Volleys+c*fifa_df.Curve+
                          b*fifa_df.Strength)/(3*b+14*c+7*d)

# %%
sn12 = fifa_df[(fifa_df['Club_Position']=='ST')].sort_values('Best Striker', ascending =False)[:5]
sn12
# Out:
#                   Name Nationality National_Position             Club  \
# 3          Luis Suárez     Uruguay                LS     FC Barcelona
# 8   Zlatan Ibrahimović      Sweden               NaN   Manchester Utd
# 22      Alexis Sánchez       Chile                LW          Arsenal
# 17       Sergio Agüero   Argentina               Sub  Manchester City
# 6   Robert Lewandowski      Poland                LS        FC Bayern
#
#    Club_Position Club_Joining  Contract_Expiry  Rating  Height Weight  \
# 3             ST   07/11/2014           2021.0      92  182 cm  85 kg
# 8             ST   07/01/2016           2017.0      90  195 cm  95 kg
# 22            ST   07/10/2014           2018.0      88  169 cm  62 kg
# 17            ST   07/28/2011           2020.0      89  173 cm  70 kg
# 6             ST   07/01/2014           2021.0      90  185 cm  79 kg
#
#    Preffered_Foot  Birth_Date  Age Preffered_Position      Work_Rate  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set(rc={'figure.figsize':(10,7)})
x12 = np.array(list(sn12['Name']))
y12 = np.array(list(sn12['Best Striker']))
plt.xlabel('Name', fontsize =20, color ='Red')
plt.ylabel('Best Striker', fontsize = 20, color ='Green')
sns.barplot(x12,y12, palette ='colorblind')
